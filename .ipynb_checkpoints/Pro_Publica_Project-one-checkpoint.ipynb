# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
import json
from json.decoder import JSONDecodeError

# Import API key
from api_keys import propublica_api_key

from api_keys import g_key

# Output File (CSV)
output_data_file = "output_data/bills.csv"

# %%
# Save config information.
#query_url = f"https://api.propublica.org/congress/v1/bills/search.json?query=megahertz"
#header = {"X-API-Key": propublica_api_key}

#response = requests.get(query_url,header).json()

#response=requests.get(query_url , headers=header).json()
#print(json.dumps(response, indent=4))

# %%
record_num1=1
congress=["114", "115", "116"]
bill_slug = []
congress1 = []
for k in range(0,len(congress)):
    for i in range(1,5000,1):
        try:
            bill_id=f"hr{i}"
            query_url = f"https://api.propublica.org/congress/v1/{congress[k]}/bills/{bill_id}.json"
            header = {"X-API-Key": propublica_api_key}
            response=requests.get(query_url , headers=header).json()
            bill_slug.append(response['results'][0]['bill_slug'])
            congress1.append(congress[k])
        except (KeyError, IndexError):
            print(f"{bill_id}: Bill not found. Skipping...")
        except JSONDecodeError as exc:
            #if exc.msg == 'Invalid \\escape':
                #text = text[:exc.pos] + '\\' + text[exc.pos:]
            
            print(f"{bill_id}: {exc.msg}")
        except:
            print ("Unexpected error")
       #If statement to handle the API call limits
        if record_num1 == 1000:
            record_num1 += 1
            time.sleep(5)
# Out:
# hr1: Bill not found. Skipping...
# hr4: Bill not found. Skipping...
# hr11: Bill not found. Skipping...
# hr13: Bill not found. Skipping...
# hr14: Bill not found. Skipping...
# hr15: Bill not found. Skipping...
# hr16: Bill not found. Skipping...
# hr17: Bill not found. Skipping...
# hr18: Bill not found. Skipping...
# hr19: Bill not found. Skipping...
# hr1269: Expecting value
# hr1285: Expecting value
# hr1287: Expecting value
# hr1300: Expecting value
# hr1311: Expecting value
# hr1735: Bill not found. Skipping...
# hr4151: Bill not found. Skipping...
# hr9: Bill not found. Skipping...
# hr11: Bill not found. Skipping...
# hr13: Bill not found. Skipping...
# hr14: Bill not found. Skipping...
# hr16: Bill not found. Skipping...
# hr17: Bill not found. Skipping...
# hr18: Bill not found. Skipping...
# hr1168: Bill not found. Skipping...
# hr2810: Bill not found. Skipping...
# Unexpected error
# Unexpected error
# Unexpected error
# Unexpected error
# Unexpected error
# hr4597: Bill not found. Skipping...
# hr4598: Bill not found. Skipping...
# hr4599: Bill not found. Skipping...
# hr4600: Expecting value
# hr4601: Expecting value
# hr4602: Expecting value
# hr4603: Expecting value
# hr4604: Expecting value
# hr4605: Expecting value
# hr4606: Expecting value
# hr4607: Expecting value
# hr4608: Expecting value
# hr4609: Expecting value
# hr4610: Expecting value
# hr4611: Expecting value
# hr4612: Expecting value
# hr4613: Expecting value
# hr4614: Expecting value
# hr4615: Expecting value
# hr4616: Expecting value
# hr4617: Expecting value
# hr4618: Expecting value
# hr4619: Expecting value
# hr4620: Expecting value
# hr4621: Expecting value
# hr4622: Expecting value
# hr4623: Expecting value
# hr4624: Expecting value
# hr4625: Expecting value
# hr4626: Expecting value
# hr4627: Expecting value
# hr4628: Expecting value
# hr4629: Expecting value
# hr4630: Expecting value
# hr4631: Expecting value
# hr4632: Expecting value
# hr4633: Expecting value
# hr4634: Expecting value
# hr4635: Expecting value
# hr4636: Expecting value
# hr4637: Expecting value
# hr4638: Expecting value
# hr4639: Expecting value
# hr4640: Expecting value
# hr4641: Expecting value
# hr4642: Expecting value
# hr4643: Expecting value
# hr4644: Expecting value
# hr4645: Expecting value
# hr4646: Expecting value
# hr4647: Expecting value
# hr4648: Expecting value
# hr4649: Expecting value
# hr4650: Expecting value
# hr4651: Expecting value
# hr4652: Expecting value
# hr4653: Expecting value
# hr4654: Expecting value
# hr4655: Expecting value
# hr4656: Expecting value
# hr4657: Expecting value
# hr4658: Expecting value
# hr4659: Expecting value
# hr4660: Expecting value
# hr4661: Expecting value
# hr4662: Expecting value
# hr4663: Expecting value
# hr4664: Expecting value
# hr4665: Expecting value
# hr4666: Expecting value
# hr4667: Expecting value
# hr2: Bill not found. Skipping...
# hr10: Bill not found. Skipping...
# hr11: Bill not found. Skipping...
# hr12: Bill not found. Skipping...
# hr13: Bill not found. Skipping...
# hr14: Bill not found. Skipping...
# hr15: Bill not found. Skipping...
# hr16: Bill not found. Skipping...
# hr17: Bill not found. Skipping...
# hr18: Bill not found. Skipping...

# %%
bills_df=pd.DataFrame({
                    "bill_slug":bill_slug,
                    "congress":congress1,
                    "bill_id":"" ,
                    "bill_type":"" ,   
                    "bill_uri":"" ,
                    "short_title":"" , 
                    "sponsor_title":"" ,
                    "sponsor_id":"" , 
                    "sponsor_name":"" ,
                    "sponsor_state":"" ,
                    "sponsor_party":"" ,
                    "congressdotgov_url":"" ,
                    "govtrack_url":"" ,
                    "introduced_date":"" ,
                    "active":"" ,
                    "house_passage":"" ,
                    "senate_passage":"" ,
                    "enacted":"" ,
                    "vetoed":"" ,
                    "cosponsors":"" ,
                    "cosponsors_by_party_D":"" ,
                    "cosponsors_by_party_R":"" ,
                    "committees":"" ,
                    "committee_codes":"" ,
                    "primary_subject":""   
                    })
bills_df
# Out:
#       bill_slug congress bill_id bill_type bill_uri short_title sponsor_title  \
# 0           hr2      114
# 1           hr3      114
# 2           hr5      114
# 3           hr6      114
# 4           hr7      114
# ...         ...      ...     ...       ...      ...         ...           ...
# 14880    hr4995      116
# 14881    hr4996      116
# 14882    hr4997      116
# 14883    hr4998      116
# 14884    hr4999      116
#
#       sponsor_id sponsor_name sponsor_state  ... house_passage senate_passage  \
# 0                                            ...
# 1                                            ...
# 2                                            ...
# 3                                            ...
# 4                                            ...
# ...          ...          ...           ...  ...           ...            ...
# 14880                                        ...
# 14881                                        ...
# 14882                                        ...
# 14883                                        ...
# 14884                                        ...
#
#       enacted vetoed cosponsors cosponsors_by_party_D cosponsors_by_party_R  \
# 0
# 1
# 2
# 3
# 4
# ...       ...    ...        ...                   ...                   ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#       committees committee_codes primary_subject
# 0
# 1
# 2
# 3
# 4
# ...          ...             ...             ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
# [14885 rows x 25 columns]

# %%
record_num=1
for  index, row in bills_df.iterrows():
    query_url = f"https://api.propublica.org/congress/v1/{row['congress']}/bills/{row['bill_slug']}.json"
    header = {"X-API-Key": propublica_api_key}
    response=requests.get(query_url , headers=header).json()
        #print(json.dumps(response, indent=4))
        #print(json.dumps(response['results'][0]['bill_id'], indent=4))
    try:
        bills_df.loc[index, 'bill_id'] = response['results'][0]['bill_id']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'bill_type'] = response['results'][0]['bill_type']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'bill_uri'] = response['results'][0]['bill_uri']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'short_title'] = response['results'][0]['short_title']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'sponsor_title'] = response['results'][0]['sponsor_title']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'sponsor_id'] = response['results'][0]['sponsor_id']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'sponsor_name'] = response['results'][0]['sponsor']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'sponsor_state'] = response['results'][0]['sponsor_state']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'sponsor_party'] = response['results'][0]['sponsor_party']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'congressdotgov_url'] = response['results'][0]['congressdotgov_url']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'govtrack_url'] = response['results'][0]['govtrack_url']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'introduced_date'] = response['results'][0]['introduced_date']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'active'] = response['results'][0]['active']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'house_passage'] = response['results'][0]['house_passage']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'senate_passage'] = response['results'][0]['senate_passage']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'enacted'] = response['results'][0]['enacted']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'vetoed'] = response['results'][0]['vetoed']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'cosponsors'] = response['results'][0]['cosponsors']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'cosponsors_by_party_D'] = response['results'][0]['cosponsors_by_party']['D']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
    try:
        bills_df.loc[index, 'cosponsors_by_party_R'] = response['results'][0]['cosponsors_by_party']['R']
    except:
        print(f"{row['bill_id']}: Missing data in source. Skipping...")
# hr4036-116: Missing data in source. Skipping...
# hr4039-116: Missing data in source. Skipping...
# hr4040-116: Missing data in source. Skipping...
# hr4041-116: Missing data in source. Skipping...
# hr4042-116: Missing data in source. Skipping...
# hr4042-116: Missing data in source. Skipping...
# hr4046-116: Missing data in source. Skipping...
# hr4047-116: Missing data in source. Skipping...
# hr4047-116: Missing data in source. Skipping...
# hr4048-116: Missing data in source. Skipping...
# hr4048-116: Missing data in source. Skipping...
# hr4049-116: Missing data in source. Skipping...
# hr4050-116: Missing data in source. Skipping...
# hr4051-116: Missing data in source. Skipping...
# hr4053-116: Missing data in source. Skipping...
# hr4053-116: Missing data in source. Skipping...
# hr4054-116: Missing data in source. Skipping...
# hr4054-116: Missing data in source. Skipping...
# hr4055-116: Missing data in source. Skipping...
# hr4055-116: Missing data in source. Skipping...
# hr4057-116: Missing data in source. Skipping...
# hr4058-116: Missing data in source. Skipping...
# hr4059-116: Missing data in source. Skipping...
# hr4062-116: Missing data in source. Skipping...
# hr4062-116: Missing data in source. Skipping...
# hr4063-116: Missing data in source. Skipping...
# hr4064-116: Missing data in source. Skipping...
# hr4065-116: Missing data in source. Skipping...
# hr4066-116: Missing data in source. Skipping...
# hr4069-116: Missing data in source. Skipping...
# hr4074-116: Missing data in source. Skipping...
# hr4076-116: Missing data in source. Skipping...
# hr4079-116: Missing data in source. Skipping...
# hr4079-116: Missing data in source. Skipping...
# hr4080-116: Missing data in source. Skipping...
# hr4080-116: Missing data in source. Skipping...
# hr4081-116: Missing data in source. Skipping...
# hr4081-116: Missing data in source. Skipping...
# hr4082-116: Missing data in source. Skipping...
# hr4082-116: Missing data in source. Skipping...
# hr4083-116: Missing data in source. Skipping...
# hr4084-116: Missing data in source. Skipping...
# hr4085-116: Missing data in source. Skipping...
# hr4087-116: Missing data in source. Skipping...
# hr4088-116: Missing data in source. Skipping...
# hr4089-116: Missing data in source. Skipping...
# hr4090-116: Missing data in source. Skipping...
# hr4093-116: Missing data in source. Skipping...
# hr4094-116: Missing data in source. Skipping...
# hr4095-116: Missing data in source. Skipping...
# hr4098-116: Missing data in source. Skipping...
# hr4099-116: Missing data in source. Skipping...
# hr4101-116: Missing data in source. Skipping...
# hr4102-116: Missing data in source. Skipping...
# hr4106-116: Missing data in source. Skipping...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     317             else:
# --> 318                 raise SocketError(str(e))
#     319         except OpenSSL.SSL.ZeroReturnError:
#
# ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')",))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-41974e94139f> in <module>
#       3     query_url = f"https://api.propublica.org/congress/v1/{row['congress']}/bills/{row['bill_slug']}.json"
#       4     header = {"X-API-Key": propublica_api_key}
# ----> 5     response=requests.get(query_url , headers=header).json()
#       6         #print(json.dumps(response, indent=4))
#       7         #print(json.dumps(response['results'][0]['bill_id'], indent=4))
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')",))

# %%
bills_df
# Out:
#       bill_slug congress  bill_id bill_type  \
# 0           hr2      114  hr2-114        hr
# 1           hr3      114  hr3-114        hr
# 2           hr5      114  hr5-114        hr
# 3           hr6      114  hr6-114        hr
# 4           hr7      114  hr7-114        hr
# ...         ...      ...      ...       ...
# 14880    hr4995      116
# 14881    hr4996      116
# 14882    hr4997      116
# 14883    hr4998      116
# 14884    hr4999      116
#
#                                                 bill_uri  \
# 0      https://api.propublica.org/congress/v1/114/bil...
# 1      https://api.propublica.org/congress/v1/114/bil...
# 2      https://api.propublica.org/congress/v1/114/bil...
# 3      https://api.propublica.org/congress/v1/114/bil...
# 4      https://api.propublica.org/congress/v1/114/bil...
# ...                                                  ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#                                              short_title sponsor_title  \
# 0      Medicare Access and CHIP Reauthorization Act o...          Rep.
# 1                               Keystone XL Pipeline Act          Rep.
# 2                                    Student Success Act          Rep.
# 3                                 21st Century Cures Act          Rep.
# 4      No Taxpayer Funding for Abortion and Abortion ...          Rep.
# ...                                                  ...           ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#       sponsor_id          sponsor_name sponsor_state  ... house_passage  \
# 0        B001248    Michael C. Burgess            TX  ...    2015-03-26
# 1        C001096          Kevin Cramer            ND  ...    2015-01-09
# 2        K000363            John Kline            MN  ...    2015-07-08
# 3        U000031            Fred Upton            MI  ...    2015-07-10
# 4        S000522  Christopher H. Smith            NJ  ...    2015-01-22
# ...          ...                   ...           ...  ...           ...
# 14880                                                 ...
# 14881                                                 ...
# 14882                                                 ...
# 14883                                                 ...
# 14884                                                 ...
#
#       senate_passage     enacted vetoed cosponsors cosponsors_by_party_D  \
# 0         2015-04-14  2015-04-16   None         13                     6
# 1               None        None   None         30
# 2               None        None   None         11
# 3               None        None   None        230                   121
# 4               None        None   None         29                     1
# ...              ...         ...    ...        ...                   ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#       cosponsors_by_party_R  \
# 0                         7
# 1                        30
# 2                        11
# 3                       109
# 4                        28
# ...                     ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#                                               committees  \
# 0                      House Natural Resources Committee
# 1                      House Natural Resources Committee
# 2                     House Financial Services Committee
# 3      Senate Health, Education, Labor, and Pensions ...
# 4                               Senate Finance Committee
# ...                                                  ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#                             committee_codes  \
# 0      [HSBU, HSII, HSAG, HSJU, HSWM, HSIF]
# 1                        [HSPW, HSII, HSIF]
# 2                              [HSED, HSBA]
# 3                        [SSHR, HSWM, HSIF]
# 4                  [SSFI, HSJU, HSWM, HSIF]
# ...                                     ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
#                                    primary_subject
# 0                                           Health
# 1                                           Energy
# 2                                        Education
# 3                                           Health
# 4      Civil Rights and Liberties, Minority Issues
# ...                                            ...
# 14880
# 14881
# 14882
# 14883
# 14884
#
# [14885 rows x 25 columns]

# %%
output_data_file1 = "output_data/bills.csv"
output_path = os.path.join( output_data_file1)
bills_df.to_csv(output_path, index=False, header=True)

# %%
#bill_type = []
#bill_uri=[]
#short_title=[]
#sponsor_title=[]
#sponsor_id=[]
#sponsor_name=[]
#sponsor_state=[]
#sponsor_party=[]
#congressdotgov_url=[]
#govtrack_url=[]
#introduced_date=[]
#active=[]
#house_passage=[]
#senate_passage=[]
#enacted=[]
#vetoed=[]
#cosponsors=[]
#cosponsors_by_party_D=[]
#cosponsors_by_party_R=[]
#committees=[]
#committee_codes=[]
#primary_subject=[]
#
#       
#congress="115"
##bill_id="hr1"
##id = 1
#for i in range(1,20,1):
#    try:
#        bill_id=f"hr{i}"
#        query_url = f"https://api.propublica.org/congress/v1/{congress}/bills/{bill_id}.json"
#        header = {"X-API-Key": propublica_api_key}
#        response=requests.get(query_url , headers=header).json()
#        #print(json.dumps(response, indent=4))
#        #print(json.dumps(response['results'][0]['bill_id'], indent=4))
#        bill_id1.append(response['results'][0]['bill_id'])
#        bill_type.append(response['results'][0]['bill_type'])
#        bill_uri.append(response['results'][0]['bill_uri'])
#        short_title.append(response['results'][0]['short_title'])
#        sponsor_title.append(response['results'][0]['sponsor_title'])
#        sponsor_id.append(response['results'][0]['sponsor_id'])
#        sponsor_name.append(response['results'][0]['sponsor'])
#        sponsor_state.append(response['results'][0]['sponsor_state'])
#        sponsor_party.append(response['results'][0]['sponsor_party'])
#        congressdotgov_url.append(response['results'][0]['congressdotgov_url'])
#        govtrack_url.append(response['results'][0]['govtrack_url'])
#        introduced_date.append(response['results'][0]['introduced_date'])
#        active.append(response['results'][0]['active'])
#        house_passage.append(response['results'][0]['house_passage'])
#        senate_passage.append(response['results'][0]['senate_passage'])
#        enacted.append(response['results'][0]['enacted'])
#        vetoed.append(response['results'][0]['vetoed'])
#        cosponsors.append(response['results'][0]['cosponsors'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    try:   
#        cosponsors_by_party_D.append(response['results'][0]['cosponsors_by_party']['D'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    try:
#        cosponsors_by_party_R.append(response['results'][0]['cosponsors_by_party']['R'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    try:
#        committees.append(response['results'][0]['committees'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    try:
#        committee_codes.append(response['results'][0]['committee_codes'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    try:
#        primary_subject.append(response['results'][0]['primary_subject'])
#    except (KeyError, IndexError):
#        print(f"{bill_id}: Bill not found. Skipping...")
#    
#
##response = requests.get(query_url,header).json()
#
#
##print(json.dumps(response, indent=4))
#
##https://api.propublica.org/congress/v1/{congress}/bills/{bill-id}.json

# %%
#print(len(bill_type))
#print(len(bill_id1))
#print(len(bill_uri))
#print(len(short_title))
#print(len(sponsor_title))
#print(len(sponsor_id))
#print(len(sponsor_name))
#print(len(sponsor_state))
#print(len(sponsor_party))
#print(len(sponsor_state))
#print(len(sponsor_party))
#print(len(congressdotgov_url))
#print(len(govtrack_url))
#print(len(introduced_date))
#print(len(active))
#print(len(house_passage))
#print(len(senate_passage))
#print(len(enacted))
#print(len(vetoed))
#print(len(cosponsors))
#print(len(cosponsors_by_party_D))
#print(len(cosponsors_by_party_R))
#print(len(committees))
#print(len(committee_codes))
#print(len(primary_subject))
#
##import files
##hr_2017_2018_data = pd.read_csv("output_data/data.json")
##hr_2017_2018_data=pd.read_json("resources/data.json") #,orient="columns")
##hr_2017_2018_df=pd.read_json(hr_2017_2018_data['']).to_json(), orient='index')

# %%
#bills_df=pd.DataFrame({
#                    "bill_id":bill_id1 ,
#                    "bill_type":bill_type ,   
#                    "bill_uri":bill_uri ,
#                    "short_title":short_title , 
#                    "sponsor_title":sponsor_title ,
#                    "sponsor_id":sponsor_id , 
#                    "sponsor_name":sponsor_name ,
#                    "sponsor_state":sponsor_state ,
#                    "sponsor_party":sponsor_party ,
#                    "congressdotgov_url":congressdotgov_url ,
#                    "govtrack_url":govtrack_url ,
#                    "introduced_date":introduced_date ,
#                    "active":active ,
#                    "house_passage":house_passage ,
#                    "senate_passage":senate_passage ,
#                    "enacted":enacted ,
#                    "vetoed":vetoed ,
#                    "cosponsors":cosponsors ,
#                    "cosponsors_by_party_D":cosponsors_by_party_D ,
#                    "cosponsors_by_party_R":cosponsors_by_party_R ,
#                    "committees":committees ,
#                    "committee_codes":committee_codes ,
#                    "primary_subject":primary_subject   
#                    })
#
#bills_df
