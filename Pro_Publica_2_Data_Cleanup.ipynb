# %% [markdown]
# # Merge all bills files and cleanup data

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import stats
import os
import json
from json.decoder import JSONDecodeError
import glob
import plotly.graph_objects as go
import plotly.express as px
import datetime as dt
import scipy.stats as st

# %%
#Read all output data files and add them to a data frame

path = r'output_data/' # use your path
all_files = glob.glob(path + "/bills*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

bills_df = pd.concat(li, axis=0, ignore_index=True)

# %%
bills_df.head()
# Out:
#   bill_slug  congress  bill_id bill_type  \
# 0       hr1       112  hr1-112        hr
# 1       hr2       112  hr2-112        hr
# 2       hr3       112  hr3-112        hr
# 3       hr4       112  hr4-112        hr
# 4       hr5       112  hr5-112        hr
#
#                                             bill_uri  \
# 0  https://api.propublica.org/congress/v1/112/bil...
# 1  https://api.propublica.org/congress/v1/112/bil...
# 2  https://api.propublica.org/congress/v1/112/bil...
# 3  https://api.propublica.org/congress/v1/112/bil...
# 4  https://api.propublica.org/congress/v1/112/bil...
#
#                                          short_title sponsor_title sponsor_id  \
# 0                                                NaN           NaN    R000395
# 1      Repealing the Job-Killing Health Care Law Act          Rep.    C001046
# 2               No Taxpayer Funding for Abortion Act          Rep.    S000522
# 3  Comprehensive 1099 Taxpayer Protection and Rep...          Rep.    L000517
# 4                Protecting Access to Healthcare Act          Rep.    G000550
#
#            sponsor_name sponsor_state  ... house_passage senate_passage  \
# 0         Harold Rogers            KY  ...    2011-02-19     2011-03-09
# 1           Eric Cantor            VA  ...    2011-01-19            NaN
# 2  Christopher H. Smith            NJ  ...    2011-05-04            NaN
# 3           Dan Lungren            CA  ...    2011-03-03            NaN
# 4          Phil Gingrey            GA  ...    2012-03-22            NaN
#
#   enacted vetoed cosponsors cosponsors_by_party_D cosponsors_by_party_R  \
# 0     NaN    NaN        0.0                   NaN                   NaN
# 1     NaN    NaN      182.0                   NaN                 182.0
# 2     NaN    NaN      227.0                  12.0                 216.0
# 3     NaN    NaN      273.0                  37.0                 236.0
# 4     NaN    NaN      134.0                   3.0                 133.0
#
#                                           committees committee_codes  \
# 0                 House Appropriations; House Budget              []
# 1  House Energy and Commerce; House Education and...              []
# 2  House Judiciary; House Energy and Commerce; Ho...              []
# 3                               House Ways and Means              []
# 4         House Judiciary; House Energy and Commerce              []
#
#    primary_subject
# 0              NaN
# 1           Health
# 2           Health
# 3         Taxation
# 4           Health
#
# [5 rows x 25 columns]

# %%
#Check for dup bills in data set by bill id
 
dup_bills=bills_df.groupby(["bill_id"]).size().sort_values(ascending=False).reset_index(name="Frequency")
dup_bills=dup_bills.loc[dup_bills["Frequency"]>1]
print("-----Duplicate bills-----")
print(dup_bills)

# Create a clean DataFrame by dropping the duplicate bill by its ID.
clean_bills_df = bills_df.drop_duplicates(subset=(["bill_id"]), keep='first')
clean_bills_df.head()
# Out:
# -----Duplicate bills-----
# Empty DataFrame
# Columns: [bill_id, Frequency]
# Index: []
#   bill_slug  congress  bill_id bill_type  \
# 0       hr1       112  hr1-112        hr
# 1       hr2       112  hr2-112        hr
# 2       hr3       112  hr3-112        hr
# 3       hr4       112  hr4-112        hr
# 4       hr5       112  hr5-112        hr
#
#                                             bill_uri  \
# 0  https://api.propublica.org/congress/v1/112/bil...
# 1  https://api.propublica.org/congress/v1/112/bil...
# 2  https://api.propublica.org/congress/v1/112/bil...
# 3  https://api.propublica.org/congress/v1/112/bil...
# 4  https://api.propublica.org/congress/v1/112/bil...
#
#                                          short_title sponsor_title sponsor_id  \
# 0                                                NaN           NaN    R000395
# 1      Repealing the Job-Killing Health Care Law Act          Rep.    C001046
# 2               No Taxpayer Funding for Abortion Act          Rep.    S000522
# 3  Comprehensive 1099 Taxpayer Protection and Rep...          Rep.    L000517
# 4                Protecting Access to Healthcare Act          Rep.    G000550
#
#            sponsor_name sponsor_state  ... house_passage senate_passage  \
# 0         Harold Rogers            KY  ...    2011-02-19     2011-03-09
# 1           Eric Cantor            VA  ...    2011-01-19            NaN
# 2  Christopher H. Smith            NJ  ...    2011-05-04            NaN
# 3           Dan Lungren            CA  ...    2011-03-03            NaN
# 4          Phil Gingrey            GA  ...    2012-03-22            NaN
#
#   enacted vetoed cosponsors cosponsors_by_party_D cosponsors_by_party_R  \
# 0     NaN    NaN        0.0                   NaN                   NaN
# 1     NaN    NaN      182.0                   NaN                 182.0
# 2     NaN    NaN      227.0                  12.0                 216.0
# 3     NaN    NaN      273.0                  37.0                 236.0
# 4     NaN    NaN      134.0                   3.0                 133.0
#
#                                           committees committee_codes  \
# 0                 House Appropriations; House Budget              []
# 1  House Energy and Commerce; House Education and...              []
# 2  House Judiciary; House Energy and Commerce; Ho...              []
# 3                               House Ways and Means              []
# 4         House Judiciary; House Energy and Commerce              []
#
#    primary_subject
# 0              NaN
# 1           Health
# 2           Health
# 3         Taxation
# 4           Health
#
# [5 rows x 25 columns]

# %%
#Check for invalid dataset/unuseful dataset  based on bill introduced date

invalid_data=clean_bills_df['introduced_date'].isna().groupby(clean_bills_df.congress, sort=False).sum().reset_index()
invalid_list=invalid_data.loc[invalid_data['introduced_date'] == True]
invalid_list
# Out:
#    congress  introduced_date
# 0       112             True

# %%
#drop bills with congress number in invalid list
clean_bills_df = clean_bills_df[~clean_bills_df['congress'].isin(invalid_list['congress'])]
clean_bills_df.head()
# Out:
#      bill_slug  congress  bill_id bill_type  \
# 6725       hr1       113  hr1-113        hr
# 6726       hr2       113  hr2-113        hr
# 6727       hr3       113  hr3-113        hr
# 6728       hr4       113  hr4-113        hr
# 6729       hr5       113  hr5-113        hr
#
#                                                bill_uri  \
# 6725  https://api.propublica.org/congress/v1/113/bil...
# 6726  https://api.propublica.org/congress/v1/113/bil...
# 6727  https://api.propublica.org/congress/v1/113/bil...
# 6728  https://api.propublica.org/congress/v1/113/bil...
# 6729  https://api.propublica.org/congress/v1/113/bil...
#
#                                             short_title sponsor_title  \
# 6725                             Tax Reform Act of 2014          Rep.
# 6726  American Energy Solutions for Lower Costs and ...          Rep.
# 6727                        Northern Route Approval Act          Rep.
# 6728                               Jobs for America Act          Rep.
# 6729                                Student Success Act          Rep.
#
#      sponsor_id sponsor_name sponsor_state  ... house_passage senate_passage  \
# 6725    C000071    Dave Camp            MI  ...           NaN            NaN
# 6726    T000459    Lee Terry            NE  ...    2014-09-18            NaN
# 6727    T000459    Lee Terry            NE  ...    2013-05-22            NaN
# 6728    C000071    Dave Camp            MI  ...    2014-09-18            NaN
# 6729    K000363   John Kline            MN  ...    2013-07-19            NaN
#
#      enacted vetoed cosponsors cosponsors_by_party_D cosponsors_by_party_R  \
# 6725     NaN    NaN        0.0                   NaN                   NaN
# 6726     NaN    NaN       15.0                   NaN                  15.0
# 6727     NaN    NaN      134.0                   2.0                 132.0
# 6728     NaN    NaN        4.0                   NaN                   4.0
# 6729     NaN    NaN       12.0                   NaN                  12.0
#
#                                              committees  \
# 6725                     House Ways and Means Committee
# 6726                House Energy and Commerce Committee
# 6727                  House Natural Resources Committee
# 6728                          House Judiciary Committee
# 6729  Senate Health, Education, Labor, and Pensions ...
#
#                                         committee_codes  \
# 6725                                           ['HSWM']
# 6726           ['HSII', 'HSSY', 'HSJU', 'HSPW', 'HSIF']
# 6727                           ['HSII', 'HSPW', 'HSIF']
# 6728  ['HSWM', 'HSSM', 'HSII', 'HSAG', 'HSBA', 'HSJU...
# 6729                           ['SSHR', 'HSED', 'HSBA']
#
#                    primary_subject
# 6725                      Taxation
# 6726                        Energy
# 6727                        Energy
# 6728  Economics and Public Finance
# 6729                     Education
#
# [5 rows x 25 columns]

# %%
#Write the clean data into a csv file to be used for the project
output_data_file = "output_data/clean_bills.csv"
output_path = os.path.join(output_data_file)
clean_bills_df.to_csv(output_path, index=False, header=True)
